# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
odi = pd.read_csv("ODI-2022.csv", sep=';')

# %%
odi.head()
# Out:
#          Tijdstempel          What programme are you in?  \
# 0  4-5-2022 12:12:07             artificial intelligence
# 1  4-5-2022 12:12:07                            big data
# 2  4-5-2022 12:12:09              Computational  Science
# 3  4-5-2022 12:12:09  Bioinformatics and Systems Biology
# 4  4-5-2022 12:12:15                                  AI
#
#   Have you taken a course on machine learning?  \
# 0                                          yes
# 1                                          yes
# 2                                          yes
# 3                                          yes
# 4                                          yes
#
#   Have you taken a course on information retrieval?  \
# 0                                                 0
# 1                                                 0
# 2                                                 1
# 3                                                 0
# 4                                                 1
#
# ...

# %%
odi['What programme are you in?'].value_counts()
# Out:
# AI                                     39
# Artificial Intelligence                31
# Computational Science                  23
# Business Analytics                     14
# CS                                     10
#                                        ..
# Masters EOR                             1
# Fin: QRM                                1
# artificial intelligence                 1
# Artificial Intelligence MsC             1
# Bio informatics and systems biology     1
# Name: What programme are you in?, Length: 123, dtype: int64

# %%
odi['Have you taken a course on machine learning?'].value_counts()
# Out:
# yes        185
# no         112
# unknown      7
# Name: Have you taken a course on machine learning?, dtype: int64

# %%
plt.hist(odi['Have you taken a course on machine learning?'])
# Out:
# (array([185.,   0.,   0.,   0.,   0., 112.,   0.,   0.,   0.,   7.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
odi['When is your birthday (date)?'].value_counts()
# Out:
# 08-05-1998      3
# 29-05-1998      2
# 02/07/1997      2
# 18-06-1999      2
# 1999            2
#                ..
# 19.03.1995      1
# 02-22-2222      1
# 13/04/1999      1
# 11.03.98        1
# 23 December     1
# Name: When is your birthday (date)?, Length: 295, dtype: int64

# %%
odi['Time you went to be Yesterday'].value_counts()
# Out:
# 23:00    21
# 12       13
# 23:30     7
# 00:00     7
# 22:00     6
#          ..
# 0:30      1
# 2230      1
# ??        1
# Ω         1
# 23;00     1
# Name: Time you went to be Yesterday, Length: 177, dtype: int64

# %%
yesterday = odi['Time you went to be Yesterday']

# %%
cleaned = []
for times in yesterday:
    time = str(times).replace(" ", "")
    print(time)
    #if ":" in str(y):
        #print(y)
# Out:
# 23:00
# 32
# x
# 14:00
# 07:20
# 2130
# 00:35
# 23
# 23:00
# 12hours
# Banana
# 00:00
# tobe?
# 00:00
# 12:00
# 4yearsago
# noon
# 12:55
# 12
# 12
# 20:00
# definitely7
# 03:00
# Ja
# 2.30AM
# Yellow
# 23:32
# ?
# 12
# 23.30
# 12:30
# 90
# 23
# 5
# 5
# What?
# ?
# 01.30
# 1:34
# 09:00
# midnight
# huh
# Yesterday
# 11
# 23:30
# 1
# 23:00
# 0200
# Today
# Haha
# 4
# 01:00
# 10:00pm
# 23:45
# 24
# 12.00
# Yes
# nan
# 00:34
# 13:15
# 7
# Gym
# 2.00
# 23:00
# 22:30
# 15:30
# 12
# yes
# 11pm
# 2am
# 2300
# 0530am
# 12
# 13:12
# 01.00
# 4o'clock
# 4:35
# 12
# 12
# 2:00
# 12:00
# Wot
# 10:45
# 20.09
# 00:00
# 10
# 22:00
# 24
# 12
# 12:45
# 6am
# 23
# 7hours
# 12
# 12.15
# Ω
# 9.00am
# Idonotknow
# 10:00
# 00:45
# 11.30pm
# 6
# 23:00
# 10:21:39
# 4:20
# idk
# 12
# 00:55
# 23:30
# 12
# today
# 0100
# 23:30
# 01:30
# 21:20
# 2am
# 45
# 3AM
# 23:30
# 01:30
# DizzyMissLizzywasaterriblesongtoendHelp!with
# 02:20
# 1.00
# 23:00
# 23:40
# 05:00
# 1am
# 00
# 20.30
# 01.30
# 23:00
# 23:00
# 2:30
# ...
