# %%
import pandas as pd
df = pd.read_csv('ODII.csv')
df2 = df.rename({'Chocolate makes you.....': 'Y'}, axis=1)
df2.describe()
df3 = df2.drop('Y', 1)
df3.describe()
df4 = df3.drop('Tijdstempel',1)
df4.describe()
# Out:
#        What programme are you in?  \
# count                         304
# unique                        123
# top                            AI
# freq                           39
#
#        Have you taken a course on machine learning?  \
# count                                           304
# unique                                            3
# top                                             yes
# freq                                            185
#
#        Have you taken a course on information retrieval?  \
# count                                                304
# unique                                                 3
# top                                                    0
# freq                                                 202
#
#        Have you taken a course on statistics?  \
# count                                     304
# unique                                      3
# top                                        mu
# ...

# %%
df['Give a random number'].max()
# Out:
# '∞'

# %%
df['Give a random number'].min()
# Out:
# '-1'

# %%
ai = ["A.I", "Aritificial Intelligence", "artificial intelligence","AI","ai","Masters in Artificial Intelligence","AI for health","Artificial intelligence","MSc. AI at UvA ","MSc AI","Master Artificial Intelligence","MSc AI @ UvA","Masters AI","Ai","Artificial intelligence master","MSc Artificial Intelligence","MSc AI","MSc in AI","M Artificial Intelligence","AI Masters","Master AI","AI Cognitive Science Track","VU Master of AI"]
d = dict.fromkeys(ai,'AI')
df4["What programme are you in?"] = df4["What programme are you in?"].replace(d)

# %%
df4.describe()
# Out:
#        What programme are you in?  \
# count                         304
# unique                        106
# top                            AI
# freq                           66
#
#        Have you taken a course on machine learning?  \
# count                                           304
# unique                                            3
# top                                             yes
# freq                                            185
#
#        Have you taken a course on information retrieval?  \
# count                                                304
# unique                                                 3
# top                                                    0
# freq                                                 202
#
#        Have you taken a course on statistics?  \
# count                                     304
# unique                                      3
# top                                        mu
# ...

# %%
df5=df4.drop('Give a random number',1)

# %%
df5.describe()
# Out:
#        What programme are you in?  \
# count                         304
# unique                        106
# top                            AI
# freq                           66
#
#        Have you taken a course on machine learning?  \
# count                                           304
# unique                                            3
# top                                             yes
# freq                                            185
#
#        Have you taken a course on information retrieval?  \
# count                                                304
# unique                                                 3
# top                                                    0
# freq                                                 202
#
#        Have you taken a course on statistics?  \
# count                                     304
# unique                                      3
# top                                        mu
# ...

# %%
df6=df5.drop("Did you stand up?",1)

# %%
df6.describe()
# Out:
#        What programme are you in?  \
# count                         304
# unique                        106
# top                            AI
# freq                           66
#
#        Have you taken a course on machine learning?  \
# count                                           304
# unique                                            3
# top                                             yes
# freq                                            185
#
#        Have you taken a course on information retrieval?  \
# count                                                304
# unique                                                 3
# top                                                    0
# freq                                                 202
#
#        Have you taken a course on statistics?  \
# count                                     304
# unique                                      3
# top                                        mu
# ...

# %%
df6.head()
# Out:
#            What programme are you in?  \
# 0                                  AI
# 1                            big data
# 2              Computational  Science
# 3  Bioinformatics and Systems Biology
# 4                                  AI
#
#   Have you taken a course on machine learning?  \
# 0                                          yes
# 1                                          yes
# 2                                          yes
# 3                                          yes
# 4                                          yes
#
#   Have you taken a course on information retrieval?  \
# 0                                                 0
# 1                                                 0
# 2                                                 1
# 3                                                 0
# 4                                                 1
#
#   Have you taken a course on statistics?  \
# 0                                     mu
# ...

# %%
bool1 = ["0"]
bool2 = ["1"]
ir1 = dict.fromkeys(bool1,"no")
df6["Have you taken a course on information retrieval?"] = df6["Have you taken a course on information retrieval?"].replace(ir1)

# %%
ir2 = dict.fromkeys(bool2,"yes")
df6["Have you taken a course on information retrieval?"] = df6["Have you taken a course on information retrieval?"].replace(ir2)

# %%
bool3 = ["mu"]
bool4 = ["sigma"]
bool5 = ["nee"]
bool6 = ["ja"]

# %%
st1 = dict.fromkeys(bool3,"no")
df6["Have you taken a course on statistics?"] = df6["Have you taken a course on statistics?"].replace(st1)

# %%
st2 = dict.fromkeys(bool4,"yes")
df6["Have you taken a course on statistics?"] = df6["Have you taken a course on statistics?"].replace(st2)

# %%
db1 = dict.fromkeys(bool5,"no")
df6["Have you taken a course on databases?"] = df6["Have you taken a course on databases?"].replace(db1)

# %%
db2 = dict.fromkeys(bool6,"yes")
df6["Have you taken a course on databases?"] = df6["Have you taken a course on databases?"].replace(db2)

# %%
df6.describe()
# Out:
#        What programme are you in?  \
# count                         304
# unique                        106
# top                            AI
# freq                           66
#
#        Have you taken a course on machine learning?  \
# count                                           304
# unique                                            3
# top                                             yes
# freq                                            185
#
#        Have you taken a course on information retrieval?  \
# count                                                304
# unique                                                 3
# top                                                   no
# freq                                                 202
#
#        Have you taken a course on statistics?  \
# count                                     304
# unique                                      3
# top                                        no
# ...

# %%
df7=df6.drop(df6.columns[[7,9]], axis=1)

# %%
df7.describe()
# Out:
#        What programme are you in?  \
# count                         304
# unique                        106
# top                            AI
# freq                           66
#
#        Have you taken a course on machine learning?  \
# count                                           304
# unique                                            3
# top                                             yes
# freq                                            185
#
#        Have you taken a course on information retrieval?  \
# count                                                304
# unique                                                 3
# top                                                   no
# freq                                                 202
#
#        Have you taken a course on statistics?  \
# count                                     304
# unique                                      3
# top                                        no
# ...

# %%
df7.head()
# Out:
#            What programme are you in?  \
# 0                                  AI
# 1                            big data
# 2              Computational  Science
# 3  Bioinformatics and Systems Biology
# 4                                  AI
#
#   Have you taken a course on machine learning?  \
# 0                                          yes
# 1                                          yes
# 2                                          yes
# 3                                          yes
# 4                                          yes
#
#   Have you taken a course on information retrieval?  \
# 0                                                no
# 1                                                no
# 2                                               yes
# 3                                                no
# 4                                               yes
#
#   Have you taken a course on statistics?  \
# 0                                     no
# ...

# %%
print(df7["What programme are you in?"])
# Out:
# 0                                      AI
# 1                                big data
# 2                  Computational  Science
# 3      Bioinformatics and Systems Biology
# 4                                      AI
#                       ...
# 299                                    AI
# 300                                     E
# 301             MSc Computational Science
# 302               Artificial Intelligence
# 303                    Business Analytics
# Name: What programme are you in?, Length: 304, dtype: object

# %%
ai2 = ["Artificial Intelligence"]
d2 = dict.fromkeys(ai2,'AI')
df7["What programme are you in?"] = df7["What programme are you in?"].replace(d2)

# %%
print(df7["What programme are you in?"])
# Out:
# 0                                      AI
# 1                                big data
# 2                  Computational  Science
# 3      Bioinformatics and Systems Biology
# 4                                      AI
#                       ...
# 299                                    AI
# 300                                     E
# 301             MSc Computational Science
# 302                                    AI
# 303                    Business Analytics
# Name: What programme are you in?, Length: 304, dtype: object

# %%
df7.describe()
# Out:
#        What programme are you in?  \
# count                         304
# unique                        105
# top                            AI
# freq                           97
#
#        Have you taken a course on machine learning?  \
# count                                           304
# unique                                            3
# top                                             yes
# freq                                            185
#
#        Have you taken a course on information retrieval?  \
# count                                                304
# unique                                                 3
# top                                                   no
# freq                                                 202
#
#        Have you taken a course on statistics?  \
# count                                     304
# unique                                      3
# top                                        no
# ...

# %%
cs = ["big data","Computer Science","MSc Computer Science","Computer science","CS Big Data Engineering","Computer Science(joint degree)","CS","cs","MSc Computer science","Computer science - BDE","Master of Computer science"]
comp = dict.fromkeys(cs,'CS')
df7["What programme are you in?"] = df7["What programme are you in?"].replace(comp)

# %%
df7.describe()
# Out:
#        What programme are you in?  \
# count                         304
# unique                         97
# top                            AI
# freq                           97
#
#        Have you taken a course on machine learning?  \
# count                                           304
# unique                                            3
# top                                             yes
# freq                                            185
#
#        Have you taken a course on information retrieval?  \
# count                                                304
# unique                                                 3
# top                                                   no
# freq                                                 202
#
#        Have you taken a course on statistics?  \
# count                                     304
# unique                                      3
# top                                        no
# ...

# %%
print(df7["What programme are you in?"])
# Out:
# 0                                      AI
# 1                                      CS
# 2                  Computational  Science
# 3      Bioinformatics and Systems Biology
# 4                                      AI
#                       ...
# 299                                    AI
# 300                                     E
# 301             MSc Computational Science
# 302                                    AI
# 303                    Business Analytics
# Name: What programme are you in?, Length: 304, dtype: object

# %%
print(df7['When is your birthday (date)?'])
# Out:
# 0      02-05-1998
# 1      29-02-2000
# 2      29-06-1998
# 3      11-05-1997
# 4      03-10-1997
#           ...
# 299    01-01-1956
# 300           NaN
# 301    17-07-1995
# 302           NaN
# 303    12-05-1998
# Name: When is your birthday (date)?, Length: 304, dtype: object

# %%
df7.dropna(subset=['When is your birthday (date)?'], inplace = True)

# %%
df7.describe()
# Out:
#        What programme are you in?  \
# count                         214
# unique                         72
# top                            AI
# freq                           73
#
#        Have you taken a course on machine learning?  \
# count                                           214
# unique                                            3
# top                                             yes
# freq                                            131
#
#        Have you taken a course on information retrieval?  \
# count                                                214
# unique                                                 3
# top                                                   no
# freq                                                 148
#
#        Have you taken a course on statistics?  \
# count                                     214
# unique                                      3
# top                                        no
# ...

# %%
from datetime import datetime as dt
df7['When is your birthday (date)?'] = pd.to_datetime(df7['When is your birthday (date)?'])
df7['When is your birthday (date)?'] = df7['When is your birthday (date)?'].dt.strftime('%Y')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-6ba80d0a1fc7> in <module>
#       1 from datetime import datetime as dt
#       2 df8= pd.to_datetime(df7['When is your birthday (date)?'])
# ----> 3 df8['When is your birthday (date)?'] = df7['When is your birthday (date)?'].dt.strftime('%Y')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# ...

# %%
df7.describe()
# Out:
#        What programme are you in?  \
# count                         214
# unique                         71
# top                            AI
# freq                           74
#
#        Have you taken a course on machine learning?  \
# count                                           214
# unique                                            3
# top                                             yes
# freq                                            131
#
#        Have you taken a course on information retrieval?  \
# count                                                214
# unique                                                 3
# top                                                   no
# freq                                                 148
#
#        Have you taken a course on statistics?  \
# count                                     214
# unique                                      3
# top                                        no
# ...

# %%
print(df7['When is your birthday (date)?'])
# Out:
# 0      1998
# 1      2000
# 2      1998
# 3      1997
# 4      1997
#        ...
# 292    1997
# 294    1996
# 299    1956
# 301    1995
# 303    1998
# Name: When is your birthday (date)?, Length: 214, dtype: object

# %%
df7['When is your birthday (date)?'].value_counts()
# Out:
# 1998    56
# 1997    39
# 1999    38
# 1996    20
# 1995    16
# 2000    13
# 2001     5
# 1994     5
# 1900     4
# 1982     3
# 1991     3
# 1992     2
# 1990     2
# 1956     1
# 2003     1
# 1969     1
# 2004     1
# 1974     1
# 1989     1
# 1993     1
# 2022     1
# Name: When is your birthday (date)?, dtype: int64

# %%
df7["What programme are you in?"].value_counts()
# Out:
# AI                                           73
# CS                                           26
# Computational Science                        16
# Business Analytics                           11
# BA                                            4
#                                              ..
# IS:DS                                         1
# MSc in Bioinformatics and Systems Biology     1
# Artificial Intelligence MsC                   1
# Engineering and Policy Analysis, TU Delft     1
# Bioinformatics                                1
# Name: What programme are you in?, Length: 72, dtype: int64

# %%
ai3 = ["Artificial Intelligence MsC"]
d3= dict.fromkeys(ai3,'AI')
df7["What programme are you in?"] = df7["What programme are you in?"].replace(d3)

# %%
df7["What programme are you in?"].value_counts()
# Out:
# AI                                           74
# CS                                           26
# Computational Science                        16
# Business Analytics                           11
# Bioinformatics and Systems Biology            4
#                                              ..
# IS:DS                                         1
# MSc in Bioinformatics and Systems Biology     1
# Engineering and Policy Analysis, TU Delft     1
# Masters EOR                                   1
# Bioinformatics                                1
# Name: What programme are you in?, Length: 71, dtype: int64

# %%
df7.to_csv('clean.csv', encoding='utf-8')
# Out:
# 0                                      AI
# 1                                      CS
# 2                  Computational  Science
# 3      Bioinformatics and Systems Biology
# 4                                      AI
#                       ...
# 292                                  BISB
# 294                                    CS
# 299                                    AI
# 301             MSc Computational Science
# 303                    Business Analytics
# Name: What programme are you in?, Length: 214, dtype: object
