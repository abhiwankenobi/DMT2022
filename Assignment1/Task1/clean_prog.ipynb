# %%
import pandas as pd
df = pd.read_csv('part_clean.csv')

# %%
df.head()
# Out:
#    Unnamed: 0          What programme are you in?  \
# 0           0                                  AI
# 1           1                                  CS
# 2           2              Computational  Science
# 3           3  Bioinformatics and Systems Biology
# 4           4                                  AI
#
#   Have you taken a course on machine learning?  \
# 0                                          yes
# 1                                          yes
# 2                                          yes
# 3                                          yes
# 4                                          yes
#
#   Have you taken a course on information retrieval?  \
# 0                                                no
# 1                                                no
# 2                                               yes
# 3                                                no
# 4                                               yes
#
#   Have you taken a course on statistics?  \
# ...

# %%
ai = ["A.I", "Aritificial Intelligence", "artificial intelligence","AI","ai","Masters in Artificial Intelligence","AI for health","Artificial intelligence","MSc. AI at UvA ","MSc AI","Master Artificial Intelligence","MSc AI @ UvA","Masters AI","Ai","Artificial intelligence master","MSc Artificial Intelligence","MSc AI","MSc in AI","M Artificial Intelligence","AI Masters","Master AI","AI Cognitive Science Track","VU Master of AI","Artificial Intelligence","Artificial Intelligence MsC"]
d = dict.fromkeys(ai,'AI')
df["What programme are you in?"] = df["What programme are you in?"].replace(d)

# %%
df.head()
# Out:
#    Unnamed: 0          What programme are you in?  \
# 0           0                                  AI
# 1           1                                  CS
# 2           2              Computational  Science
# 3           3  Bioinformatics and Systems Biology
# 4           4                                  AI
#
#   Have you taken a course on machine learning?  \
# 0                                          yes
# 1                                          yes
# 2                                          yes
# 3                                          yes
# 4                                          yes
#
#   Have you taken a course on information retrieval?  \
# 0                                                no
# 1                                                no
# 2                                               yes
# 3                                                no
# 4                                               yes
#
#   Have you taken a course on statistics?  \
# ...

# %%
df["What programme are you in?"].value_counts()
# Out:
# AI                            98
# CS                            33
# Computational Science         23
# Business Analytics            14
# BA                             8
#                               ..
# Data Science                   1
# business analytics             1
# MSc Mathematics                1
# M Artificial Intelligence      1
# FinTech                        1
# Name: What programme are you in?, Length: 96, dtype: int64

# %%
df.to_csv("some_clean.csv")
