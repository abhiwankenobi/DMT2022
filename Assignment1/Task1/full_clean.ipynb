# %%
import pandas as pd

# %%
df=pd.read_csv("some_clean.csv")

# %%
df.head()
# Out:
#   What programme are you in? Have you taken a course on machine learning?  \
# 0                         AI                                          yes
# 1                         CS                                          yes
# 2                        CLS                                          yes
# 3                    Bioinfo                                          yes
# 4                         AI                                          yes
#
#   Have you taken a course on information retrieval?  \
# 0                                                no
# 1                                                no
# 2                                               yes
# 3                                                no
# 4                                               yes
#
#   Have you taken a course on statistics?  \
# 0                                     no
# 1                                     no
# 2                                     no
# ...

# %%
df["When is your birthday (date)?"].value_counts()
# Out:
# 08-05-1998    3
# 01-01-1900    3
# 16-02-1998    2
# 18-06-1999    2
# 29-05-1998    2
#              ..
# 03-08-1999    1
# 13-07-1998    1
# 04-09-1997    1
# 08-06-1999    1
# 27-06-1998    1
# Name: When is your birthday (date)?, Length: 204, dtype: int64

# %%
df.describe()
# Out:
#        What programme are you in?  \
# count                         304
# unique                         40
# top                            AI
# freq                          113
#
#        Have you taken a course on machine learning?  \
# count                                           304
# unique                                            3
# top                                             yes
# freq                                            185
#
#        Have you taken a course on information retrieval?  \
# count                                                304
# unique                                                 3
# top                                                   no
# freq                                                 202
#
#        Have you taken a course on statistics?  \
# count                                     304
# unique                                      3
# top                                        no
# ...

# %%
df.dropna(subset=['When is your birthday (date)?'], inplace = True)

# %%
df.to_csv("more_clean.csv")

# %%
df.describe()
# Out:
#        What programme are you in?  \
# count                         214
# unique                         30
# top                            AI
# freq                           85
#
#        Have you taken a course on machine learning?  \
# count                                           214
# unique                                            3
# top                                             yes
# freq                                            131
#
#        Have you taken a course on information retrieval?  \
# count                                                214
# unique                                                 3
# top                                                   no
# freq                                                 148
#
#        Have you taken a course on statistics?  \
# count                                     214
# unique                                      3
# top                                        no
# ...
