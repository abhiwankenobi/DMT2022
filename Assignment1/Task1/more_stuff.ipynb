# %%
import pandas as pd
df = pd.read_csv("some_clean.csv")

# %%
df.describe()
# Out:
#        What programme are you in?  \
# count                         291
# unique                         16
# top                            AI
# freq                          113
#
#        Have you taken a course on machine learning?  \
# count                                           304
# unique                                            3
# top                                             yes
# freq                                            185
#
#        Have you taken a course on information retrieval?  \
# count                                                304
# unique                                                 3
# top                                                   no
# freq                                                 202
#
#        Have you taken a course on statistics?  \
# count                                     304
# unique                                      3
# top                                        no
# ...

# %%
df.dropna(subset=['What programme are you in?'], inplace = True)

# %%
df.describe()
# Out:
#        What programme are you in?  \
# count                         291
# unique                         16
# top                            AI
# freq                          113
#
#        Have you taken a course on machine learning?  \
# count                                           291
# unique                                            3
# top                                             yes
# freq                                            177
#
#        Have you taken a course on information retrieval?  \
# count                                                291
# unique                                                 3
# top                                                   no
# freq                                                 196
#
#        Have you taken a course on statistics?  \
# count                                     291
# unique                                      3
# top                                        no
# ...
