# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
import seaborn as sns
from collections import Counter
from dateutil.relativedelta import relativedelta
import datetime
import copy
import pdb

# %%
pd.set_option('max_columns', None)

# %%
start = time.time()
df_train = pd.read_csv("raw_data/train_data.csv", parse_dates=[1])
df_test = pd.read_csv("raw_data/test_data.csv", parse_dates=[1])
end = time.time()
print("Train set loaded in ", end - start, " seconds.")
# Out:
# Train set loaded in  24.63033938407898  seconds.

# %%
df_train.hist(figsize=(20, 20))

# %%
df_test.hist(figsize=(20, 20))

# %%
def get_cross_val_splits(df_train, train_inds, val_inds):
    train_data= df_train.iloc[train_inds]
    X_train = train_data.loc[:, ~train_data.columns.isin(['srch_id','rel'])]
    y_train = train_data.loc[:, train_data.columns.isin(['rel'])]
    train_groups = train_data.groupby('srch_id').size().to_frame('size')['size'].to_numpy()
    
    val_data= df_train.iloc[val_inds]
    #We need to keep the id for later predictions
    X_val = val_data.loc[:, ~val_data.columns.isin(['srch_id','rel'])]
    X_val_with_srch_id = val_data.loc[:, ~val_data.columns.isin(['rel'])]
    y_val = val_data.loc[:, val_data.columns.isin(['rel'])]
    eval_groups = X_val_with_srch_id.groupby('srch_id').size().to_frame('size')['size'].to_numpy()
    
    return X_train, y_train, train_groups, X_val, y_val, eval_groups

# %%
# Train and Test Data have literally the same distribution 
# Is it safe to say that model overfitted to the trainset will do well on the test set?
from sklearn.model_selection import GroupShuffleSplit
gss = GroupShuffleSplit(test_size=0.1, n_splits=5, random_state = 7)
for train_inds, val_inds in gss.split(df_train, groups=df_train['srch_id']):
    X_train, y_train, train_groups, X_val, y_val, eval_groups = get_cross_val_splits(df_train, train_inds, val_inds)
    print(len(X_val))
    print(len(X_train))
    X_val.hist(figsize=(20, 20))

# %%
# Todo add mean prop_id numeric features

# %%
prop_columns = [feature for feature in df_train.columns if 'prop' in feature]
prop_columns.append('price_usd')
df_train_subset = df_train[df_test.columns]
full_data = pd.concat([df_test, df_train_subset])
full_data = full_data[prop_columns]
prop_columns.remove('prop_id')
property_df = full_data.groupby('prop_id')[prop_columns].agg(np.mean).reset_index()
property_df['prop_review_score'].fillna(-1, inplace=True)
x_train = property_df[~property_df['prop_location_score2'].isnull()]
x_test = property_df[property_df['prop_location_score2'].isnull()]
y_train = x_train['prop_location_score2']
x_train.drop(columns=['prop_location_score2'], inplace=True)
x_test.drop(columns=['prop_location_score2'], inplace=True)
from xgboost import XGBRegressor
model = XGBRegressor(n_estimators=500, objective='reg:squarederror', max_depth=7, eta=0.2, subsample=0.7, colsample_bytree=0.8, verbose=1)
model.fit(x_train, y_train, eval_set=[(x_train, y_train)], eval_metric='rmse')
preds = model.predict(x_test)
preds[preds < 0] = 0
x_train['prop_location_score2'] = y_train
x_test['prop_location_score2'] = preds
filled_prop_df = pd.concat([x_train, x_test])
filled_prop_df.to_csv('preprocessed_data/filled_prop_df.csv', index=False)
# Out:
# [15:02:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:576:
# Parameters: { "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:0.32919
# [1]	validation_0-rmse:0.27702
# [2]	validation_0-rmse:0.23762
# C:\Users\azhar\miniconda3\envs\DMT\lib\site-packages\pandas\core\frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# [3]	validation_0-rmse:0.20851
# [4]	validation_0-rmse:0.18773
# [5]	validation_0-rmse:0.17228
# [6]	validation_0-rmse:0.16200
# [7]	validation_0-rmse:0.15444
# [8]	validation_0-rmse:0.14969
# [9]	validation_0-rmse:0.14605
# [10]	validation_0-rmse:0.14369
# [11]	validation_0-rmse:0.14201
# [12]	validation_0-rmse:0.14098
# [13]	validation_0-rmse:0.13987
# [14]	validation_0-rmse:0.13918
# [15]	validation_0-rmse:0.13863
# [16]	validation_0-rmse:0.13820
# [17]	validation_0-rmse:0.13794
# [18]	validation_0-rmse:0.13765
# [19]	validation_0-rmse:0.13715
# [20]	validation_0-rmse:0.13669
# [21]	validation_0-rmse:0.13640
# [22]	validation_0-rmse:0.13608
# [23]	validation_0-rmse:0.13595
# [24]	validation_0-rmse:0.13583
# [25]	validation_0-rmse:0.13563
# [26]	validation_0-rmse:0.13553
# [27]	validation_0-rmse:0.13541
# [28]	validation_0-rmse:0.13532
# [29]	validation_0-rmse:0.13521
# [30]	validation_0-rmse:0.13496
# [31]	validation_0-rmse:0.13485
# [32]	validation_0-rmse:0.13470
# [33]	validation_0-rmse:0.13462
# [34]	validation_0-rmse:0.13456
# [35]	validation_0-rmse:0.13440
# [36]	validation_0-rmse:0.13430
# [37]	validation_0-rmse:0.13412
# [38]	validation_0-rmse:0.13405
# [39]	validation_0-rmse:0.13400
# [40]	validation_0-rmse:0.13392
# [41]	validation_0-rmse:0.13382
# [42]	validation_0-rmse:0.13370
# [43]	validation_0-rmse:0.13365
# [44]	validation_0-rmse:0.13358
# [45]	validation_0-rmse:0.13348
# [46]	validation_0-rmse:0.13340
# [47]	validation_0-rmse:0.13316
# [48]	validation_0-rmse:0.13299
# [49]	validation_0-rmse:0.13293
# [50]	validation_0-rmse:0.13285
# [51]	validation_0-rmse:0.13267
# [52]	validation_0-rmse:0.13257
# [53]	validation_0-rmse:0.13243
# [54]	validation_0-rmse:0.13231
# [55]	validation_0-rmse:0.13209
# [56]	validation_0-rmse:0.13200
# [57]	validation_0-rmse:0.13186
# [58]	validation_0-rmse:0.13179
# [59]	validation_0-rmse:0.13168
# [60]	validation_0-rmse:0.13153
# [61]	validation_0-rmse:0.13145
# [62]	validation_0-rmse:0.13135
# [63]	validation_0-rmse:0.13124
# [64]	validation_0-rmse:0.13115
# [65]	validation_0-rmse:0.13102
# [66]	validation_0-rmse:0.13097
# [67]	validation_0-rmse:0.13081
# [68]	validation_0-rmse:0.13069
# [69]	validation_0-rmse:0.13061
# [70]	validation_0-rmse:0.13056
# [71]	validation_0-rmse:0.13049
# [72]	validation_0-rmse:0.13038
# [73]	validation_0-rmse:0.13034
# [74]	validation_0-rmse:0.13027
# [75]	validation_0-rmse:0.13020
# [76]	validation_0-rmse:0.13013
# [77]	validation_0-rmse:0.12996
# [78]	validation_0-rmse:0.12982
# [79]	validation_0-rmse:0.12967
# [80]	validation_0-rmse:0.12957
# [81]	validation_0-rmse:0.12949
# [82]	validation_0-rmse:0.12937
# [83]	validation_0-rmse:0.12930
# [84]	validation_0-rmse:0.12919
# [85]	validation_0-rmse:0.12915
# [86]	validation_0-rmse:0.12908
# [87]	validation_0-rmse:0.12905
# [88]	validation_0-rmse:0.12897
# [89]	validation_0-rmse:0.12880
# [90]	validation_0-rmse:0.12867
# [91]	validation_0-rmse:0.12859
# [92]	validation_0-rmse:0.12851
# [93]	validation_0-rmse:0.12836
# [94]	validation_0-rmse:0.12829
# [95]	validation_0-rmse:0.12819
# [96]	validation_0-rmse:0.12814
# [97]	validation_0-rmse:0.12809
# [98]	validation_0-rmse:0.12803
# [99]	validation_0-rmse:0.12797
# [100]	validation_0-rmse:0.12790
# [101]	validation_0-rmse:0.12778
# [102]	validation_0-rmse:0.12761
# [103]	validation_0-rmse:0.12758
# [104]	validation_0-rmse:0.12753
# [105]	validation_0-rmse:0.12746
# [106]	validation_0-rmse:0.12738
# [107]	validation_0-rmse:0.12718
# [108]	validation_0-rmse:0.12710
# [109]	validation_0-rmse:0.12701
# [110]	validation_0-rmse:0.12692
# [111]	validation_0-rmse:0.12685
# [112]	validation_0-rmse:0.12680
# [113]	validation_0-rmse:0.12665
# [114]	validation_0-rmse:0.12657
# [115]	validation_0-rmse:0.12643
# [116]	validation_0-rmse:0.12634
# [117]	validation_0-rmse:0.12625
# [118]	validation_0-rmse:0.12616
# [119]	validation_0-rmse:0.12608
# [120]	validation_0-rmse:0.12600
# [121]	validation_0-rmse:0.12596
# [122]	validation_0-rmse:0.12582
# [123]	validation_0-rmse:0.12575
# [124]	validation_0-rmse:0.12565
# [125]	validation_0-rmse:0.12555
# [126]	validation_0-rmse:0.12545
# [127]	validation_0-rmse:0.12531
# [128]	validation_0-rmse:0.12524
# [129]	validation_0-rmse:0.12515
# [130]	validation_0-rmse:0.12510
# [131]	validation_0-rmse:0.12502
# [132]	validation_0-rmse:0.12494
# [133]	validation_0-rmse:0.12489
# [134]	validation_0-rmse:0.12480
# [135]	validation_0-rmse:0.12472
# [136]	validation_0-rmse:0.12462
# [137]	validation_0-rmse:0.12459
# [138]	validation_0-rmse:0.12452
# [139]	validation_0-rmse:0.12448
# [140]	validation_0-rmse:0.12446
# [141]	validation_0-rmse:0.12441
# [142]	validation_0-rmse:0.12434
# [143]	validation_0-rmse:0.12427
# [144]	validation_0-rmse:0.12423
# [145]	validation_0-rmse:0.12420
# [146]	validation_0-rmse:0.12415
# [147]	validation_0-rmse:0.12405
# [148]	validation_0-rmse:0.12399
# [149]	validation_0-rmse:0.12394
# [150]	validation_0-rmse:0.12388
# [151]	validation_0-rmse:0.12382
# [152]	validation_0-rmse:0.12375
# [153]	validation_0-rmse:0.12369
# [154]	validation_0-rmse:0.12362
# [155]	validation_0-rmse:0.12353
# [156]	validation_0-rmse:0.12344
# [157]	validation_0-rmse:0.12337
# [158]	validation_0-rmse:0.12331
# [159]	validation_0-rmse:0.12324
# [160]	validation_0-rmse:0.12317
# [161]	validation_0-rmse:0.12301
# [162]	validation_0-rmse:0.12296
# [163]	validation_0-rmse:0.12289
# [164]	validation_0-rmse:0.12286
# [165]	validation_0-rmse:0.12274
# [166]	validation_0-rmse:0.12268
# [167]	validation_0-rmse:0.12252
# [168]	validation_0-rmse:0.12243
# [169]	validation_0-rmse:0.12236
# [170]	validation_0-rmse:0.12227
# [171]	validation_0-rmse:0.12223
# [172]	validation_0-rmse:0.12218
# [173]	validation_0-rmse:0.12209
# [174]	validation_0-rmse:0.12201
# [175]	validation_0-rmse:0.12193
# [176]	validation_0-rmse:0.12182
# [177]	validation_0-rmse:0.12175
# [178]	validation_0-rmse:0.12169
# [179]	validation_0-rmse:0.12163
# [180]	validation_0-rmse:0.12158
# [181]	validation_0-rmse:0.12152
# [182]	validation_0-rmse:0.12146
# [183]	validation_0-rmse:0.12141
# [184]	validation_0-rmse:0.12133
# [185]	validation_0-rmse:0.12130
# [186]	validation_0-rmse:0.12123
# [187]	validation_0-rmse:0.12120
# [188]	validation_0-rmse:0.12113
# [189]	validation_0-rmse:0.12103
# [190]	validation_0-rmse:0.12097
# [191]	validation_0-rmse:0.12093
# [192]	validation_0-rmse:0.12087
# [193]	validation_0-rmse:0.12080
# [194]	validation_0-rmse:0.12068
# [195]	validation_0-rmse:0.12063
# [196]	validation_0-rmse:0.12055
# [197]	validation_0-rmse:0.12046
# [198]	validation_0-rmse:0.12038
# [199]	validation_0-rmse:0.12033
# [200]	validation_0-rmse:0.12025
# [201]	validation_0-rmse:0.12021
# [202]	validation_0-rmse:0.12015
# [203]	validation_0-rmse:0.12004
# [204]	validation_0-rmse:0.11997
# [205]	validation_0-rmse:0.11990
# [206]	validation_0-rmse:0.11980
# [207]	validation_0-rmse:0.11975
# [208]	validation_0-rmse:0.11969
# [209]	validation_0-rmse:0.11964
# [210]	validation_0-rmse:0.11956
# [211]	validation_0-rmse:0.11949
# [212]	validation_0-rmse:0.11946
# [213]	validation_0-rmse:0.11940
# [214]	validation_0-rmse:0.11935
# [215]	validation_0-rmse:0.11929
# [216]	validation_0-rmse:0.11923
# [217]	validation_0-rmse:0.11914
# [218]	validation_0-rmse:0.11905
# [219]	validation_0-rmse:0.11900
# [220]	validation_0-rmse:0.11892
# [221]	validation_0-rmse:0.11886
# [222]	validation_0-rmse:0.11881
# [223]	validation_0-rmse:0.11875
# [224]	validation_0-rmse:0.11871
# [225]	validation_0-rmse:0.11868
# [226]	validation_0-rmse:0.11861
# [227]	validation_0-rmse:0.11857
# [228]	validation_0-rmse:0.11848
# [229]	validation_0-rmse:0.11845
# [230]	validation_0-rmse:0.11837
# [231]	validation_0-rmse:0.11829
# [232]	validation_0-rmse:0.11820
# [233]	validation_0-rmse:0.11809
# [234]	validation_0-rmse:0.11804
# [235]	validation_0-rmse:0.11796
# [236]	validation_0-rmse:0.11792
# [237]	validation_0-rmse:0.11789
# [238]	validation_0-rmse:0.11779
# [239]	validation_0-rmse:0.11771
# [240]	validation_0-rmse:0.11760
# [241]	validation_0-rmse:0.11753
# [242]	validation_0-rmse:0.11747
# [243]	validation_0-rmse:0.11742
# [244]	validation_0-rmse:0.11736
# [245]	validation_0-rmse:0.11732
# [246]	validation_0-rmse:0.11729
# [247]	validation_0-rmse:0.11723
# [248]	validation_0-rmse:0.11718
# [249]	validation_0-rmse:0.11709
# [250]	validation_0-rmse:0.11704
# [251]	validation_0-rmse:0.11701
# [252]	validation_0-rmse:0.11698
# [253]	validation_0-rmse:0.11690
# [254]	validation_0-rmse:0.11685
# [255]	validation_0-rmse:0.11681
# [256]	validation_0-rmse:0.11674
# [257]	validation_0-rmse:0.11670
# [258]	validation_0-rmse:0.11662
# [259]	validation_0-rmse:0.11659
# [260]	validation_0-rmse:0.11651
# [261]	validation_0-rmse:0.11644
# [262]	validation_0-rmse:0.11639
# [263]	validation_0-rmse:0.11636
# [264]	validation_0-rmse:0.11632
# [265]	validation_0-rmse:0.11625
# [266]	validation_0-rmse:0.11617
# [267]	validation_0-rmse:0.11613
# [268]	validation_0-rmse:0.11607
# [269]	validation_0-rmse:0.11600
# [270]	validation_0-rmse:0.11595
# [271]	validation_0-rmse:0.11587
# [272]	validation_0-rmse:0.11582
# [273]	validation_0-rmse:0.11578
# [274]	validation_0-rmse:0.11570
# [275]	validation_0-rmse:0.11563
# [276]	validation_0-rmse:0.11555
# [277]	validation_0-rmse:0.11549
# [278]	validation_0-rmse:0.11546
# [279]	validation_0-rmse:0.11540
# [280]	validation_0-rmse:0.11537
# [281]	validation_0-rmse:0.11527
# [282]	validation_0-rmse:0.11521
# [283]	validation_0-rmse:0.11518
# [284]	validation_0-rmse:0.11510
# [285]	validation_0-rmse:0.11503
# [286]	validation_0-rmse:0.11495
# [287]	validation_0-rmse:0.11490
# [288]	validation_0-rmse:0.11485
# [289]	validation_0-rmse:0.11478
# [290]	validation_0-rmse:0.11473
# [291]	validation_0-rmse:0.11464
# [292]	validation_0-rmse:0.11460
# [293]	validation_0-rmse:0.11457
# [294]	validation_0-rmse:0.11453
# [295]	validation_0-rmse:0.11446
# [296]	validation_0-rmse:0.11441
# [297]	validation_0-rmse:0.11435
# [298]	validation_0-rmse:0.11432
# [299]	validation_0-rmse:0.11426
# [300]	validation_0-rmse:0.11421
# [301]	validation_0-rmse:0.11415
# [302]	validation_0-rmse:0.11408
# [303]	validation_0-rmse:0.11398
# [304]	validation_0-rmse:0.11393
# [305]	validation_0-rmse:0.11389
# [306]	validation_0-rmse:0.11385
# [307]	validation_0-rmse:0.11378
# [308]	validation_0-rmse:0.11374
# [309]	validation_0-rmse:0.11366
# [310]	validation_0-rmse:0.11363
# [311]	validation_0-rmse:0.11356
# [312]	validation_0-rmse:0.11349
# [313]	validation_0-rmse:0.11342
# [314]	validation_0-rmse:0.11337
# [315]	validation_0-rmse:0.11328
# [316]	validation_0-rmse:0.11321
# [317]	validation_0-rmse:0.11315
# [318]	validation_0-rmse:0.11309
# [319]	validation_0-rmse:0.11305
# [320]	validation_0-rmse:0.11298
# [321]	validation_0-rmse:0.11294
# [322]	validation_0-rmse:0.11292
# [323]	validation_0-rmse:0.11287
# [324]	validation_0-rmse:0.11282
# [325]	validation_0-rmse:0.11277
# [326]	validation_0-rmse:0.11271
# [327]	validation_0-rmse:0.11268
# [328]	validation_0-rmse:0.11265
# [329]	validation_0-rmse:0.11259
# [330]	validation_0-rmse:0.11255
# [331]	validation_0-rmse:0.11251
# [332]	validation_0-rmse:0.11248
# [333]	validation_0-rmse:0.11246
# [334]	validation_0-rmse:0.11242
# [335]	validation_0-rmse:0.11237
# [336]	validation_0-rmse:0.11231
# [337]	validation_0-rmse:0.11224
# [338]	validation_0-rmse:0.11220
# [339]	validation_0-rmse:0.11215
# [340]	validation_0-rmse:0.11213
# [341]	validation_0-rmse:0.11208
# [342]	validation_0-rmse:0.11204
# [343]	validation_0-rmse:0.11198
# [344]	validation_0-rmse:0.11194
# [345]	validation_0-rmse:0.11193
# [346]	validation_0-rmse:0.11187
# [347]	validation_0-rmse:0.11184
# [348]	validation_0-rmse:0.11181
# [349]	validation_0-rmse:0.11179
# [350]	validation_0-rmse:0.11174
# [351]	validation_0-rmse:0.11169
# [352]	validation_0-rmse:0.11167
# [353]	validation_0-rmse:0.11164
# [354]	validation_0-rmse:0.11160
# [355]	validation_0-rmse:0.11153
# [356]	validation_0-rmse:0.11148
# [357]	validation_0-rmse:0.11139
# [358]	validation_0-rmse:0.11130
# [359]	validation_0-rmse:0.11126
# [360]	validation_0-rmse:0.11120
# [361]	validation_0-rmse:0.11117
# [362]	validation_0-rmse:0.11111
# [363]	validation_0-rmse:0.11105
# [364]	validation_0-rmse:0.11101
# [365]	validation_0-rmse:0.11091
# [366]	validation_0-rmse:0.11086
# [367]	validation_0-rmse:0.11084
# [368]	validation_0-rmse:0.11079
# [369]	validation_0-rmse:0.11074
# [370]	validation_0-rmse:0.11060
# [371]	validation_0-rmse:0.11055
# [372]	validation_0-rmse:0.11049
# [373]	validation_0-rmse:0.11046
# [374]	validation_0-rmse:0.11042
# [375]	validation_0-rmse:0.11039
# [376]	validation_0-rmse:0.11035
# [377]	validation_0-rmse:0.11028
# [378]	validation_0-rmse:0.11024
# [379]	validation_0-rmse:0.11019
# [380]	validation_0-rmse:0.11011
# [381]	validation_0-rmse:0.11004
# [382]	validation_0-rmse:0.10999
# [383]	validation_0-rmse:0.10994
# [384]	validation_0-rmse:0.10990
# [385]	validation_0-rmse:0.10986
# [386]	validation_0-rmse:0.10981
# [387]	validation_0-rmse:0.10979
# [388]	validation_0-rmse:0.10974
# [389]	validation_0-rmse:0.10970
# [390]	validation_0-rmse:0.10964
# [391]	validation_0-rmse:0.10957
# [392]	validation_0-rmse:0.10947
# [393]	validation_0-rmse:0.10938
# [394]	validation_0-rmse:0.10935
# [395]	validation_0-rmse:0.10928
# [396]	validation_0-rmse:0.10917
# [397]	validation_0-rmse:0.10912
# [398]	validation_0-rmse:0.10908
# [399]	validation_0-rmse:0.10901
# [400]	validation_0-rmse:0.10898
# [401]	validation_0-rmse:0.10892
# [402]	validation_0-rmse:0.10889
# [403]	validation_0-rmse:0.10884
# [404]	validation_0-rmse:0.10878
# [405]	validation_0-rmse:0.10873
# [406]	validation_0-rmse:0.10869
# [407]	validation_0-rmse:0.10863
# [408]	validation_0-rmse:0.10860
# [409]	validation_0-rmse:0.10854
# [410]	validation_0-rmse:0.10848
# [411]	validation_0-rmse:0.10843
# [412]	validation_0-rmse:0.10837
# [413]	validation_0-rmse:0.10831
# [414]	validation_0-rmse:0.10827
# [415]	validation_0-rmse:0.10822
# [416]	validation_0-rmse:0.10816
# [417]	validation_0-rmse:0.10811
# [418]	validation_0-rmse:0.10806
# [419]	validation_0-rmse:0.10798
# [420]	validation_0-rmse:0.10794
# [421]	validation_0-rmse:0.10790
# [422]	validation_0-rmse:0.10784
# [423]	validation_0-rmse:0.10781
# [424]	validation_0-rmse:0.10773
# [425]	validation_0-rmse:0.10769
# [426]	validation_0-rmse:0.10764
# [427]	validation_0-rmse:0.10759
# [428]	validation_0-rmse:0.10749
# [429]	validation_0-rmse:0.10741
# [430]	validation_0-rmse:0.10737
# [431]	validation_0-rmse:0.10730
# [432]	validation_0-rmse:0.10724
# [433]	validation_0-rmse:0.10721
# [434]	validation_0-rmse:0.10711
# [435]	validation_0-rmse:0.10706
# [436]	validation_0-rmse:0.10701
# [437]	validation_0-rmse:0.10696
# [438]	validation_0-rmse:0.10692
# [439]	validation_0-rmse:0.10686
# [440]	validation_0-rmse:0.10683
# [441]	validation_0-rmse:0.10680
# [442]	validation_0-rmse:0.10676
# [443]	validation_0-rmse:0.10670
# [444]	validation_0-rmse:0.10662
# [445]	validation_0-rmse:0.10657
# [446]	validation_0-rmse:0.10653
# [447]	validation_0-rmse:0.10648
# [448]	validation_0-rmse:0.10642
# [449]	validation_0-rmse:0.10636
# [450]	validation_0-rmse:0.10628
# [451]	validation_0-rmse:0.10624
# [452]	validation_0-rmse:0.10620
# [453]	validation_0-rmse:0.10616
# [454]	validation_0-rmse:0.10610
# [455]	validation_0-rmse:0.10606
# [456]	validation_0-rmse:0.10604
# [457]	validation_0-rmse:0.10598
# [458]	validation_0-rmse:0.10594
# [459]	validation_0-rmse:0.10591
# [460]	validation_0-rmse:0.10585
# [461]	validation_0-rmse:0.10581
# [462]	validation_0-rmse:0.10575
# [463]	validation_0-rmse:0.10572
# [464]	validation_0-rmse:0.10570
# [465]	validation_0-rmse:0.10565
# [466]	validation_0-rmse:0.10560
# [467]	validation_0-rmse:0.10554
# [468]	validation_0-rmse:0.10550
# [469]	validation_0-rmse:0.10545
# [470]	validation_0-rmse:0.10542
# [471]	validation_0-rmse:0.10538
# [472]	validation_0-rmse:0.10534
# [473]	validation_0-rmse:0.10530
# [474]	validation_0-rmse:0.10524
# [475]	validation_0-rmse:0.10521
# [476]	validation_0-rmse:0.10511
# [477]	validation_0-rmse:0.10507
# [478]	validation_0-rmse:0.10503
# [479]	validation_0-rmse:0.10496
# [480]	validation_0-rmse:0.10492
# [481]	validation_0-rmse:0.10486
# [482]	validation_0-rmse:0.10479
# [483]	validation_0-rmse:0.10475
# [484]	validation_0-rmse:0.10471
# [485]	validation_0-rmse:0.10465
# [486]	validation_0-rmse:0.10463
# [487]	validation_0-rmse:0.10459
# [488]	validation_0-rmse:0.10454
# [489]	validation_0-rmse:0.10443
# [490]	validation_0-rmse:0.10441
# [491]	validation_0-rmse:0.10437
# [492]	validation_0-rmse:0.10431
# [493]	validation_0-rmse:0.10427
# [494]	validation_0-rmse:0.10423
# [495]	validation_0-rmse:0.10417
# [496]	validation_0-rmse:0.10412
# [497]	validation_0-rmse:0.10410
# [498]	validation_0-rmse:0.10403
# [499]	validation_0-rmse:0.10399
# C:\Users\azhar\miniconda3\envs\DMT\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\azhar\miniconda3\envs\DMT\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
prop_columns
# Out:
# ['prop_country_id',
#  'prop_starrating',
#  'prop_review_score',
#  'prop_brand_bool',
#  'prop_location_score1',
#  'prop_location_score2',
#  'prop_log_historical_price',
#  'price_usd']

# %%
def add_normalised_prop_features(df):
    df_clone = copy.deepcopy(df)
    filled_prop_df = pd.read_csv('preprocessed_data/filled_prop_df.csv')
    selector = pd.DataFrame(filled_prop_df.groupby('prop_id')['price_usd'].mean())
    selector.columns =  ['price_usd_mean']
    df_clone = pd.merge(df_clone, selector, how='left', on='prop_id')
    
    selector = pd.DataFrame(filled_prop_df.groupby('prop_id')['prop_location_score2'].mean())
    selector.columns =  ['prop_location_score2_new']
    df_clone = pd.merge(df_clone, selector, how='left', on='prop_id')
    
    df_clone.drop(columns=['prop_location_score2'], inplace=True)
    
    return df_clone

# %%
df_test = add_normalised_prop_features(df_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-d65f5f6bd9bf> in <module>
# ----> 1 df_test = add_normalised_prop_features(df_test)
#
# NameError: name 'add_normalised_prop_features' is not defined

# %%
filled_prop_df = pd.read_csv('preprocessed_data/filled_prop_df.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-4fb482e58bfa> in <module>
# ----> 1 filled_prop_df = pd.read_csv('preprocessed_data/filled_prop_df.csv', index=False)
#
# TypeError: read_csv() got an unexpected keyword argument 'index'

# %%
filled_prop_df.head()
# Out:
#    Unnamed: 0  prop_id  prop_country_id  prop_starrating  prop_review_score  \
# 0           1        2              219                0                4.0
# 1           2        3              219                3                3.5
# 2           3        4              109                5                4.5
# 3           5        6              158                3                0.0
# 4           6        7               31                0                5.0
#
#    prop_brand_bool  prop_location_score1  prop_log_historical_price  \
# 0                1                  0.69                   3.300000
# 1                1                  0.69                   4.165122
# 2                1                  4.88                   4.965000
# 3                0                  2.30                   3.664000
# 4                0                  6.49                   4.374286
#
#     price_usd  prop_location_score2
# 0   96.272727              0.036100
# 1  109.026098              0.035055
# 2  468.611818              0.115500
# 3   46.498000              0.018763
# 4  139.577143              0.124700

# %%
filled_prop_df_new.head()
# Out:
#    prop_id  prop_country_id  prop_starrating  prop_review_score  \
# 1        2              219                0                4.0
# 2        3              219                3                3.5
# 3        4              109                5                4.5
# 5        6              158                3                0.0
# 6        7               31                0                5.0
#
#    prop_brand_bool  prop_location_score1  prop_log_historical_price  \
# 1                1                  0.69                   3.740000
# 2                1                  0.69                   4.140465
# 3                1                  4.88                   4.914048
# 5                0                  2.30                   3.592353
# 6                0                  6.49                   4.035000
#
#     price_usd  prop_location_score2
# 1   97.149655              0.066790
# 2  117.853895              0.026578
# 3  485.960952              0.115500
# 5   47.250000              0.018408
# 6  148.463571              0.124700
